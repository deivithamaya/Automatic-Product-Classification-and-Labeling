# %% [markdown]
# ### Transformation of the dataset

# %%
import sys
sys.path.append("C:/Users/rim18/OneDrive/Documentos/GitHub/Final-Project-Anyone-AI---Automated-product-categorization-for-e-commerce-with-AI")
import src.dataset_transform as dt 
datas = dt.transform_dataset('C:/Users/rim18/OneDrive/Documentos/GitHub/Final-Project-Anyone-AI---Automated-product-categorization-for-e-commerce-with-AI/dataset/products.json')

# %%
datas.head(3)
# Out:
#                                               name      type  \
# 0                Duracell - AAA Batteries (4-Pack)  HardGood
# 1  Duracell - AA 1.5V CopperTop Batteries (4-Pack)  HardGood
# 2                 Duracell - AA Batteries (8-Pack)  HardGood
#
#                                          description       image  \
# 0  Compatible with select electronic devices; AAA...   43900.jpg
# 1  Long-lasting energy; DURALOCK Power Preserve t...   48530.jpg
# 2  Compatible with select electronic devices; AA ...  127687.jpg
#
#                   subcat1_name subcat2_name subcat3_name subcat4_name  \
# 0  Connected Home & Housewares   Housewares        Other        Other
# 1  Connected Home & Housewares   Housewares        Other        Other
# 2  Connected Home & Housewares   Housewares        Other        Other
#
#   subcat5_name
# 0         None
# 1         None
# 2         None

# %%
datas.describe()
# Out:
#                                         name      type  \
# count                                  51645     51646
# unique                                 48557         6
# top     Lenmar - Lithium-Ion Battery - Black  HardGood
# freq                                      31     46103
#
#                                               description      image  \
# count                                               51646      51646
# unique                                              38537      51646
# top     Perfect gift card? Piece of cake. All Best Buy...  43900.jpg
# freq                                                  370          1
#
#        subcat1_name subcat2_name subcat3_name subcat4_name subcat5_name
# count         51646        50891        45003        26158         5646
# unique           13           25           20           17           31
# top      Appliances        Other        Other        Other        Other
# freq           9317        15697        28751        18224         1972

# %%
data_final_json = 'C:/Users/rim18/OneDrive/Documentos/GitHub/Final-Project-Anyone-AI---Automated-product-categorization-for-e-commerce-with-AI/dataset/processed_data.json'
datas.to_json(data_final_json, orient='records', lines=True)
